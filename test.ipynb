# %% [markdown]
# ## Becoming a Data Scientist Challenge!

# %% [markdown]
# You work for a clothing company that has recently released a new clothing product - leggings.The company has been receiving some negative feedback from customers mentioning they are not sure which size to purchase.
#
# **You are tasked with coming up with a way to suggest which size the customer should purchase.**
#
# **The data available to you contains:**
# * Previous customers who have purchased leggings and are happy with the selected size
# * The size of leggings purchased
# * Height of customer
# * Weight of customer
#
# **Using the information provided, make a recommendation to the following 5 customers on the size of leggings they should purchase.**
# * Customer A: 60 inches Height, 125 lbs Weight
# * Customer B: 60 inches Height, 110 lbs Weight
# * Customer C: 64 inches Height, 145 lbs Weight
# * Customer D: 66 inches Height, 145 lbs Weight
# * Customer E: 67 inches Height, 180 lbs Weight

# %% [markdown]
# We will import and use a python package called Pandas to handle a lot of data steps for us. Below we will import the package, read in our data, and print it so that we can see what it looks like.
#
# **You can run the code by either clicking on the box and pressing shift + enter, or by clicking the 'Run' button on the top of the page.**

# %%
import pandas as pd

data = pd.read_csv('weight-height.csv')
print(data)

# %% [markdown]
# Decide which feature you will use as the x_component, the y_component, and the label.  Define them below.

# %%
# This is how you define a variable in python
example_variable = 'an example variable'

# Define the model variables now and run the code by pressing shift + return
x_component =
y_component = 
label =

# %% [markdown]
# Now we are going to use a python library, plotly, to plot and view our data.  Do you notice any clusters?

# %%
import plotly.express as px

fig = px.scatter(data, x=x_component, y=y_component, color=label)
fig.show()

# %% [markdown]
# Below, we will add data points for our unknonwn customers.  We will add them to our original dataframe and plot them.

# %%
unknown_samples = pd.DataFrame([
    [60, 125, 'unknown'], #Customer A
    [60, 110, 'unknown'], #Customer B
    [64, 145, 'unknown'], #Customer C
    [66, 145, 'unknown'], #Customer D
    [67, 180, 'unknown'] #Customer E
], columns=['Height', 'Weight', 'size'])

fig2 = px.scatter(df.append(unknown_samples), x=x_feature, y=y_feature, color=label)
fig2.show()

# %% [markdown]
# Which sizes do you think should be suggested to these customers? Set them as variables below:

# %%
customer_a = 
customer_b = 
customer_c = 
customer_d = 
customer_e =

# %% [markdown]
# ## Challenge Question! Try answering this on your own.  The first to answer correctly wins a prize so come tell me your answer once you think you've found it out!
#
# Note: You must be able to show/explain your math for how you got to your answer to be eligible - no guessing!
#
# **Which size would you recommend for an individual that is 62 inches Height and 140 lbs Weight?**
#
# hint - below are the following centroid locations for each cluster:
# * small: (60.4, 106.5)
# * medium: (62.5, 128.5)
# * large: (65.2, 143.8)
# * xlarge: (66.8, 163.8)
#
# Refer to the powerpoint slides for the needed distance formula!

# %% [markdown]
# # Challenge Question 2!
#
# Some information was shared with your company about other items these unknown customers have liked in the past based on fit.
# * Customers A and B liked the blue leggings with pockets
# * Customer C liked the pink joggers
# * Customer D and E liked the black running shorts
# * Customer E also liked the white track suit
#
# Based on this information, what product(s) would you recommend to a customer to try who is:
# * 60 inches Height and 145 lbs Weight?
# * 67 inches Height and 165 lbs Weight?
# * 68 inches Height and 180 lbs Weight?

# %% [markdown]
# That was a lot of math! I hope that doesn't overwhelm you.  This is not typically what I would be required to do every day.  During the beginning of my presentation I mentioned that Python is the preferred language because it has so much support by the Data Science community.  Specifically for this problem, we have packages with prebuilt algorithms we can rely on to perform this math automatically for us.  See the code below to predict sizes for each of our unknown customers using the same math and process you did by hand above.
